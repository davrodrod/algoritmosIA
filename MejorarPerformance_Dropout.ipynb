# %% [markdown]
# <a href="https://colab.research.google.com/github/davrodrod/algorirmosIA/blob/master/MejorarPerformance_Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dropuout es un método que reduce el overfitting del training dataset, y hace al model más robusto.
#
# Esto se hace durante el entrenamiento, y se lleva a cabo ignorando o desechando un número de salidas de una capa. Esto tiene el efecto de hacer que la capa parezca como una capa con un número diferente de conexiones a la capa anterior.
#
# Tiene el efecto de insertar ruido en el proceso de entrenamiento, forzando a los nodos dentro de una capa a, probabilisticamente, tomar más o menos responsabilidad en las salidas.
#
# Puede anadirse dropout como una capa anterior a la capa en la que quieres que lleguen las salidas eliminadas.
#
# Puede emplearse en MLP, CNN y RNN, aunque existen versiones especializadas en RNN y CNN
#
# En el siguiente ejemplo se inserta un dropout del 50% entre la primera capa oculta y la capa de salida

# %%
# Fuente https://machinelearningmastery.com/tensorflow-tutorial-deep-learning-with-tf-keras/

from sklearn.datasets import make_classification
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

#create the dataset
X, y = make_classification(n_samples=1000, n_classes=2, random_state=1)
#determine the number of input features
n_features = X.shape[1]
#define model
model=Sequential()
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
#compile the model
model.compile(optimizer='adam', loss='binary_crossentropy')
#fit the model
model.fit(X,y, epochs=100, batch_size=32)
model.summary()
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0531
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9980
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9430
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7899
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7845
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7596
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6962
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6733
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6375
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6124
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6039
# Epoch 12/100
# ...
